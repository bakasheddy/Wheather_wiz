# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final data.csv')

# %%
df
# Out:
#                     time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0       2013-01-01T00:00                 22.9                       18.8
# 1       2013-01-01T01:00                 22.3                       18.3
# 2       2013-01-01T02:00                 21.8                       17.8
# 3       2013-01-01T03:00                 21.4                       17.5
# 4       2013-01-01T04:00                 21.0                       17.0
# ...                  ...                  ...                        ...
# 364127  2023-05-21T20:00                 27.5                       31.5
# 364128  2023-05-21T21:00                 27.4                       31.5
# 364129  2023-05-21T22:00                 27.2                       31.7
# 364130  2023-05-21T23:00                 27.1                       32.4
# 364131  2023-05-22T00:00                 27.0                       32.0
#
#         surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# 0                        955.7                 0.0        0.0             0.0
# 1                        955.4                 0.0        0.0             0.0
# 2                        954.8                 0.0        0.0             0.0
# 3                        954.4                 0.0        0.0             0.0
# 4                        954.0                 0.0        0.0             0.0
# ...                        ...                 ...        ...             ...
# 364127                  1009.6                 0.0        0.0            47.0
# 364128                  1010.5                 0.0        0.0            47.0
# 364129                  1011.3                 0.0        0.0            51.0
# 364130                  1012.1                 0.0        0.0            49.0
# 364131                  1011.8                 0.1        0.1            49.0
#
#         windspeed_10m (km/h)  winddirection_10m (°)   city
# 0                       15.0                   27.0  Abuja
# 1                       14.3                   28.0  Abuja
# 2                       13.7                   30.0  Abuja
# 3                       13.3                   33.0  Abuja
# 4                       13.2                   35.0  Abuja
# ...                      ...                    ...    ...
# 364127                  16.4                  213.0  Lagos
# 364128                  15.1                  220.0  Lagos
# 364129                  13.2                  227.0  Lagos
# 364130                   7.4                  223.0  Lagos
# 364131                   9.1                  198.0  Lagos
#
# [364132 rows x 10 columns]

# %%
sns.heatmap(data= df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        temperature_2m (°C)  apparent_temperature (°C)  surface_pressure (hPa)  \
# count        364132.000000              364132.000000           364132.000000
# mean             27.341947                  30.118975              980.317761
# std               3.836115                   4.407279               19.780040
# min              16.000000                  12.000000              949.400000
# 25%              24.500000                  27.600000              964.650000
# 50%              26.700000                  30.300000              977.100000
# 75%              29.600000                  32.800000              992.975000
# max              41.800000                  44.600000             1018.200000
#
#        precipitation (mm)      rain (mm)  cloudcover (%)  \
# count       364132.000000  364132.000000   364132.000000
# mean             0.138122       0.138122       42.460220
# std              0.573147       0.573147       32.383437
# min              0.000000       0.000000        0.000000
# 25%              0.000000       0.000000       16.000000
# 50%              0.000000       0.000000       35.000000
# 75%              0.000000       0.000000       66.000000
# max             23.000000      23.000000      100.000000
#
#        windspeed_10m (km/h)  winddirection_10m (°)
# count         364132.000000          364132.000000
# mean               7.600938             191.939247
# std                4.132927              79.395154
# min                0.000000               2.000000
# 25%                4.500000             153.000000
# 50%                6.800000             210.000000
# 75%               10.100000             239.000000
# max               29.800000             360.000000

# %%
#function to categorize balance 
# Define the thresholds for high, mid, and low balance
high_threshold = df['apparent_temperature (°C)'].quantile(0.75)
mid_threshold = df['apparent_temperature (°C)'].quantile(0.5)
low_threshold = df['apparent_temperature (°C)'].quantile(0.25)

# Define a function to categorize the temperature column
def categorize(x):
    if balance >= high_threshold:
        return 'high'
    elif balance >= mid_threshold:
        return 'mid'
    else:
        return 'low'
    
# Create a new column called balance_category by applying the categorize_balance function to the balance column
df['temp_category'] = df['apparent_temperature (°C)'].apply(categorize)

# %%
df
# Out:
#                     time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0       2013-01-01T00:00                 22.9                       18.8
# 1       2013-01-01T01:00                 22.3                       18.3
# 2       2013-01-01T02:00                 21.8                       17.8
# 3       2013-01-01T03:00                 21.4                       17.5
# 4       2013-01-01T04:00                 21.0                       17.0
# ...                  ...                  ...                        ...
# 364127  2023-05-21T20:00                 27.5                       31.5
# 364128  2023-05-21T21:00                 27.4                       31.5
# 364129  2023-05-21T22:00                 27.2                       31.7
# 364130  2023-05-21T23:00                 27.1                       32.4
# 364131  2023-05-22T00:00                 27.0                       32.0
#
#         surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# 0                        955.7                 0.0        0.0             0.0
# 1                        955.4                 0.0        0.0             0.0
# 2                        954.8                 0.0        0.0             0.0
# 3                        954.4                 0.0        0.0             0.0
# 4                        954.0                 0.0        0.0             0.0
# ...                        ...                 ...        ...             ...
# 364127                  1009.6                 0.0        0.0            47.0
# 364128                  1010.5                 0.0        0.0            47.0
# 364129                  1011.3                 0.0        0.0            51.0
# 364130                  1012.1                 0.0        0.0            49.0
# 364131                  1011.8                 0.1        0.1            49.0
#
#         windspeed_10m (km/h)  winddirection_10m (°)   city temp_category
# 0                       15.0                   27.0  Abuja           low
# 1                       14.3                   28.0  Abuja           low
# 2                       13.7                   30.0  Abuja           low
# 3                       13.3                   33.0  Abuja           low
# 4                       13.2                   35.0  Abuja           low
# ...                      ...                    ...    ...           ...
# 364127                  16.4                  213.0  Lagos           mid
# 364128                  15.1                  220.0  Lagos           mid
# 364129                  13.2                  227.0  Lagos           mid
# 364130                   7.4                  223.0  Lagos           mid
# 364131                   9.1                  198.0  Lagos           mid
#
# [364132 rows x 11 columns]

# %%
sns.countplot(df, x='temp_category')
# Out:
# <Axes: xlabel='temp_category', ylabel='count'>

# %%
df['apparent_temperature (°C)'] = df['apparent_temperature (°C)'].r('apparent_temperature')

# %%
df
# Out:
#                     time  temperature_2m (°C) apparent_temperature (°C)  \
# 0       2013-01-01T00:00                 22.9      apparent_temperature
# 1       2013-01-01T01:00                 22.3      apparent_temperature
# 2       2013-01-01T02:00                 21.8      apparent_temperature
# 3       2013-01-01T03:00                 21.4      apparent_temperature
# 4       2013-01-01T04:00                 21.0      apparent_temperature
# ...                  ...                  ...                       ...
# 364127  2023-05-21T20:00                 27.5      apparent_temperature
# 364128  2023-05-21T21:00                 27.4      apparent_temperature
# 364129  2023-05-21T22:00                 27.2      apparent_temperature
# 364130  2023-05-21T23:00                 27.1      apparent_temperature
# 364131  2023-05-22T00:00                 27.0      apparent_temperature
#
#         surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# 0                        955.7                 0.0        0.0             0.0
# 1                        955.4                 0.0        0.0             0.0
# 2                        954.8                 0.0        0.0             0.0
# 3                        954.4                 0.0        0.0             0.0
# 4                        954.0                 0.0        0.0             0.0
# ...                        ...                 ...        ...             ...
# 364127                  1009.6                 0.0        0.0            47.0
# 364128                  1010.5                 0.0        0.0            47.0
# 364129                  1011.3                 0.0        0.0            51.0
# 364130                  1012.1                 0.0        0.0            49.0
# 364131                  1011.8                 0.1        0.1            49.0
#
#         windspeed_10m (km/h)  winddirection_10m (°)   city temp_category
# 0                       15.0                   27.0  Abuja           low
# 1                       14.3                   28.0  Abuja           low
# 2                       13.7                   30.0  Abuja           low
# 3                       13.3                   33.0  Abuja           low
# 4                       13.2                   35.0  Abuja           low
# ...                      ...                    ...    ...           ...
# 364127                  16.4                  213.0  Lagos           mid
# 364128                  15.1                  220.0  Lagos           mid
# 364129                  13.2                  227.0  Lagos           mid
# 364130                   7.4                  223.0  Lagos           mid
# 364131                   9.1                  198.0  Lagos           mid
#
# [364132 rows x 11 columns]

# %%
df.groupby('city').apparent_temperature (°C).mean()
# Out:
#   File "C:\Users\Baka sheddy.DESKTOP-H27QSPR\AppData\Local\Temp\ipykernel_9756\2042943975.py", line 1
#     df.groupby('city').apparent_temperature (°C).mean()
#                                              ^
# SyntaxError: invalid character '°' (U+00B0)
