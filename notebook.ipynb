# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('seattle-weather.csv')
df2 = pd.read_csv('weather.csv', sep='\t')
df3 = pd.read_csv('boss_sheddi.csv')

# %%
df1
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
pd.set_option('display.max_columns', None)
df2
# Out:
#        City  nearest_area__latitude  nearest_area__longitude  \
# 0    London                   51.52                    -0.11
# 1    London                   51.52                    -0.11
# 2    London                   51.52                    -0.11
# 3    London                   51.52                    -0.11
# 4    London                   51.52                    -0.11
# ..      ...                     ...                      ...
# 211  London                   51.52                    -0.11
# 212  London                   51.52                    -0.11
# 213  London                   51.52                    -0.11
# 214  London                   51.52                    -0.11
# 215  London                   51.52                    -0.11
#
#     weather__hourly__UTCdate weather__hourly__UTCtime  weather__mintempC  \
# 0                 2017-01-04                 00:00:00                  3
# 1                 2017-01-04                 01:00:00                  3
# ...

# %%
df3
# Out:
#      Unnamed: 0    City  nearest_area__latitude  nearest_area__longitude  \
# 0             0  London                   51.52                    -0.11
# 1             1  London                   51.52                    -0.11
# 2             2  London                   51.52                    -0.11
# 3             3  London                   51.52                    -0.11
# 4             4  London                   51.52                    -0.11
# ..          ...     ...                     ...                      ...
# 211         211  London                   51.52                    -0.11
# 212         212  London                   51.52                    -0.11
# 213         213  London                   51.52                    -0.11
# 214         214  London                   51.52                    -0.11
# 215         215  London                   51.52                    -0.11
#
#     weather__hourly__UTCdatetime  weather__mintempC  weather__mintempF  \
# ...

# %%
df
