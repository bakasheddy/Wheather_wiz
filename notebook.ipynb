# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('abuja.csv')
df2 = pd.read_csv('keffi.csv')
df3 = pd.read_csv('minna.csv')
df4 = pd.read_csv('lagos.csv')

# %%
df1
# Out:
#                    time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0      2014-01-01T00:00                 23.9                     49.0
# 1      2014-01-01T01:00                 22.7                     52.0
# 2      2014-01-01T02:00                 22.1                     51.0
# 3      2014-01-01T03:00                 21.5                     51.0
# 4      2014-01-01T04:00                 20.8                     53.0
# ...                 ...                  ...                      ...
# 82339  2023-05-24T19:00                  NaN                      NaN
# 82340  2023-05-24T20:00                  NaN                      NaN
# 82341  2023-05-24T21:00                  NaN                      NaN
# 82342  2023-05-24T22:00                  NaN                      NaN
# 82343  2023-05-24T23:00                  NaN                      NaN
#
#        apparent_temperature (°C)  surface_pressure (hPa)  rain (mm)  \
# ...

# %%
df1['city'] = 'Abuja'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82344 entries, 0 to 82343
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       82344 non-null  object
#  1   temperature_2m (°C)        82249 non-null  float64
#  2   relativehumidity_2m (%)    82249 non-null  float64
#  3   apparent_temperature (°C)  82249 non-null  float64
#  4   surface_pressure (hPa)     82249 non-null  float64
#  5   rain (mm)                  82249 non-null  float64
#  6   cloudcover (%)             82249 non-null  float64
#  7   windspeed_10m (km/h)       82249 non-null  float64
#  8   winddirection_10m (°)      82249 non-null  float64
#  9   city                       82344 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 6.3+ MB

# %%
df1.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          95
# relativehumidity_2m (%)      95
# apparent_temperature (°C)    95
# surface_pressure (hPa)       95
# rain (mm)                    95
# cloudcover (%)               95
# windspeed_10m (km/h)         95
# winddirection_10m (°)        95
# city                          0
# dtype: int64

# %%
df1.dropna(inplace = True)

# %%
df1.describe()
# Out:
#        temperature_2m (°C)  relativehumidity_2m (%)  \
# count         82249.000000             82249.000000
# mean             26.943687                60.597162
# std               4.162546                27.414029
# min              16.500000                 4.000000
# 25%              23.500000                34.000000
# 50%              26.200000                67.000000
# 75%              29.800000                85.000000
# max              40.000000               100.000000
#
#        apparent_temperature (°C)  surface_pressure (hPa)     rain (mm)  \
# count               82249.000000            82249.000000  82249.000000
# mean                   29.156782              956.286579      0.138912
# std                     4.652099                1.975979      0.566945
# min                    12.100000              949.400000      0.000000
# 25%                    26.500000              954.900000      0.000000
# ...

# %%
df2
# Out:
#                    time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0      2014-01-01T00:00                 25.7                     49.0
# 1      2014-01-01T01:00                 23.8                     53.0
# 2      2014-01-01T02:00                 22.9                     53.0
# 3      2014-01-01T03:00                 22.5                     52.0
# 4      2014-01-01T04:00                 22.0                     52.0
# ...                 ...                  ...                      ...
# 82339  2023-05-24T19:00                  NaN                      NaN
# 82340  2023-05-24T20:00                  NaN                      NaN
# 82341  2023-05-24T21:00                  NaN                      NaN
# 82342  2023-05-24T22:00                  NaN                      NaN
# 82343  2023-05-24T23:00                  NaN                      NaN
#
#        apparent_temperature (°C)  surface_pressure (hPa)  rain (mm)  \
# ...

# %%
df3
# Out:
#                    time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0      2014-01-01T00:00                 24.9                     30.0
# 1      2014-01-01T01:00                 24.2                     30.0
# 2      2014-01-01T02:00                 23.7                     29.0
# 3      2014-01-01T03:00                 23.3                     28.0
# 4      2014-01-01T04:00                 22.9                     27.0
# ...                 ...                  ...                      ...
# 82339  2023-05-24T19:00                  NaN                      NaN
# 82340  2023-05-24T20:00                  NaN                      NaN
# 82341  2023-05-24T21:00                  NaN                      NaN
# 82342  2023-05-24T22:00                  NaN                      NaN
# 82343  2023-05-24T23:00                  NaN                      NaN
#
#        apparent_temperature (°C)  surface_pressure (hPa)  rain (mm)  \
# ...

# %%
df4
# Out:
#                    time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0      2014-01-01T00:00                 26.1                     89.0
# 1      2014-01-01T01:00                 26.1                     89.0
# 2      2014-01-01T02:00                 26.0                     90.0
# 3      2014-01-01T03:00                 25.8                     90.0
# 4      2014-01-01T04:00                 25.5                     91.0
# ...                 ...                  ...                      ...
# 82339  2023-05-24T19:00                  NaN                      NaN
# 82340  2023-05-24T20:00                  NaN                      NaN
# 82341  2023-05-24T21:00                  NaN                      NaN
# 82342  2023-05-24T22:00                  NaN                      NaN
# 82343  2023-05-24T23:00                  NaN                      NaN
#
#        apparent_temperature (°C)  surface_pressure (hPa)  rain (mm)  \
# ...
